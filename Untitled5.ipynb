# %%
import pandas as pd

# %%
# Read the CSV file into a DataFrame
df1 = pd.read_csv('povertydata.csv')
# Out:
# /tmp/ipykernel_40861/4052457806.py:2: DtypeWarning: Columns (66,67,73,79,82,83,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('povertydata.csv')

# %%
df1
# Out:
#      Country Name Country Code  year  \
# 0     Afghanistan          AFG  1974
# 1     Afghanistan          AFG  1975
# 2     Afghanistan          AFG  1976
# 3     Afghanistan          AFG  1977
# 4     Afghanistan          AFG  1978
# ...           ...          ...   ...
# 8282     Zimbabwe          ZWE  2014
# 8283     Zimbabwe          ZWE  2015
# 8284     Zimbabwe          ZWE  2016
# 8285     Zimbabwe          ZWE  2017
# 8286     Zimbabwe          ZWE  2018
#
#       Annualized growth in per capita real survey mean consumption or income, bottom 40% (%)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8282                                                NaN
# ...

# %%
df1.columns
# Out:
# Index(['Country Name', 'Country Code', 'year',
#        'Annualized growth in per capita real survey mean consumption or income, bottom 40% (%)',
#        'Annualized growth in per capita real survey mean consumption or income, top 10% (%)',
#        'Annualized growth in per capita real survey mean consumption or income, top 60% (%)',
#        'Annualized growth in per capita real survey mean consumption or income, total population (%)',
#        'Annualized growth in per capita real survey median income or consumption expenditure (%)',
#        'GINI index (World Bank estimate)',
#        'Growth component of change in poverty at $1.90 a day (2011 PPP) (% of change)',
#        'Growth component of change in poverty at $3.20 a day (2011 PPP) (% of change)',
#        'Growth component of change in poverty at $5.50 a day (2011 PPP) (% of change)',
#        'Income share held by fourth 20%', 'Income share held by highest 10%',
# ...

# %%
df_revamped =df1[['Income share held by fourth 20%','Income share held by highest 20%','Income share held by lowest 20%','Income share held by third 20%','Income share held by highest 10%','Income share held by lowest 10%','Income share held by second 20%']]

# %%
df_revamped
# Out:
#       Income share held by fourth 20%  Income share held by highest 20%  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 8282                              NaN                               NaN
# 8283                              NaN                               NaN
# 8284                              NaN                               NaN
# 8285                             20.6                              51.1
# 8286                              NaN                               NaN
#
#       Income share held by lowest 20%  Income share held by third 20%  \
# ...

# %%
# Strip leading and trailing whitespaces from column names
df.columns = df.columns.str.strip()

# Select only the desired columns
df = df[['Country Name', 'year', 'GINI index (World Bank estimate)']]

# Drop rows with NaN values in the 'GINI index (World Bank estimate)' column
df = df.dropna(subset=['GINI index (World Bank estimate)'])

# Sort the DataFrame by the 'year' column
df = df.sort_values(by='year')

# %%
df
# Out:
#          Country Name  year  GINI index (World Bank estimate)
# 7718   United Kingdom  1974                              30.0
# 7763    United States  1974                              35.3
# 6999           Sweden  1975                              24.3
# 1126           Canada  1975                              33.3
# 2474           France  1978                              35.2
# ...               ...   ...                               ...
# 2649          Georgia  2018                              36.4
# 8077          Vietnam  2018                              35.7
# 179            Angola  2018                              51.3
# 3998  Kyrgyz Republic  2018                              27.7
# 3368        Indonesia  2018                              39.0
#
# [1674 rows x 3 columns]

# %%
import pandas as pd

# %%
import os

# %%
os.listdir('data')
# Out:
# ['PovStatsData.csv',
#  'PovStatsCountry.csv',
#  'poverty.csv',
#  'PovStatsSeries.csv',
#  'lat_long.csv',
#  'PovStatsCountry-Series.csv',
#  'PovStatsFootNote.csv']

# %%
df = pd.read_csv('povertydata.csv')
# Out:
# /tmp/ipykernel_25795/16459251.py:1: DtypeWarning: Columns (66,67,73,79,82,83,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('povertydata.csv')

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'year',
#        'Annualized growth in per capita real survey mean consumption or income, bottom 40% (%)',
#        'Annualized growth in per capita real survey mean consumption or income, top 10% (%)',
#        'Annualized growth in per capita real survey mean consumption or income, top 60% (%)',
#        'Annualized growth in per capita real survey mean consumption or income, total population (%)',
#        'Annualized growth in per capita real survey median income or consumption expenditure (%)',
#        'GINI index (World Bank estimate)',
#        'Growth component of change in poverty at $1.90 a day (2011 PPP) (% of change)',
#        'Growth component of change in poverty at $3.20 a day (2011 PPP) (% of change)',
#        'Growth component of change in poverty at $5.50 a day (2011 PPP) (% of change)',
#        'Income share held by fourth 20%', 'Income share held by highest 10%',
# ...

# %%
df = df[['Country Name','year', 'Poverty gap at $5.50 a day (2011 PPP) (% of population)']]

# %%
df = df.dropna(subset=['Poverty gap at $5.50 a day (2011 PPP) (% of population)'])

# %%
df.sort_values(by='Poverty gap at $5.50 a day (2011 PPP) (% of population)')
# Out:
#                   Country Name  year  \
# 6516                  Slovenia  1987
# 6540                  Slovenia  2011
# 6539                  Slovenia  2010
# 6538                  Slovenia  2009
# 6537                  Slovenia  2008
# ...                        ...   ...
# 4694                      Mali  1994
# 1188  Central African Republic  1992
# 1898       East Asia & Pacific  1981
# 1470          Congo, Dem. Rep.  2004
# 2847                    Guinea  1991
#
#       Poverty gap at $5.50 a day (2011 PPP) (% of population)
# 6516                                                0.0
# 6540                                                0.0
# 6539                                                0.0
# 6538                                                0.0
# 6537                                                0.0
# ...                                                 ...
# 4694                                               79.4
# ...

# %%
df = pd.read_csv('data/PovStatsData.csv')

# %%
df
# Out:
#               Country Name Country Code  \
# 0      East Asia & Pacific          EAS
# 1      East Asia & Pacific          EAS
# 2      East Asia & Pacific          EAS
# 3      East Asia & Pacific          EAS
# 4      East Asia & Pacific          EAS
# ...                    ...          ...
# 11835             Zimbabwe          ZWE
# 11836             Zimbabwe          ZWE
# 11837             Zimbabwe          ZWE
# 11838             Zimbabwe          ZWE
# 11839             Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 0      Annualized growth in per capita real survey me...     SI.SPR.PC40.ZG
# 1      Annualized growth in per capita real survey me...     SI.SPR.PT10.ZG
# 2      Annualized growth in per capita real survey me...     SI.SPR.PT60.ZG
# 3      Annualized growth in per capita real survey me...     SI.SPR.PCAP.ZG
# 4      Annualized growth in per capita real survey me...  SI.POV.XPND.MD.ZG
# ...

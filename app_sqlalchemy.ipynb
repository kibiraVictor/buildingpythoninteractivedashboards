# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import text
from sqlalchemy.pool import NullPool

# %%
connection_url = "postgresql+psycopg2://root:root@172.18.0.2:5432/povertydb"

# %%
engine = create_engine(connection_url, poolclass=NullPool)

# %%
engine.connect()

# %%
t = text("SELECT * FROM poverty_data")

# %%
with engine.connect() as connection:
    result = pd.read_sql(t, con=engine)

# %%
result.head(n=5)
# Out:
#   index Country Name Country Code  \
# 0  None        World          WLD
# 1  None        World          WLD
# 2  None        World          WLD
# 3  None        World          WLD
# 4  None        World          WLD
#
#                                       Indicator Name     Indicator Code  1974  \
# 0  Poverty headcount ratio at $1.90 a day, urban ...     SI.POV.DDAY.UR   NaN
# 1  Poverty headcount ratio at $1.90 a day, with p...  SI.POV.DDAY.16.PR   NaN
# 2  Poverty headcount ratio at $1.90 a day, with s...  SI.POV.DDAY.16.SG   NaN
# 3  Poverty headcount ratio at $1.90 a day, withou...  SI.POV.DDAY.16.PL   NaN
# 4  Poverty headcount ratio at $1.90 a day,  with ...  SI.POV.DDAY.16.ST   NaN
#
#    1975  1976  1977  1978  ...  2011  2012  2013  2014  2015  2016  2017  \
# 0   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2018  2019  Unnamed: 50
# 0   NaN   NaN         None
# 1   NaN   NaN         None
# 2   NaN   NaN         None
# 3   NaN   NaN         None
# 4   NaN   NaN         None
#
# [5 rows x 52 columns]

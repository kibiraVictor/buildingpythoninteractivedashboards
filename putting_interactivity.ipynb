# %%
import pandas as pd
import os

# %%
os.listdir('data')
# Out:
# ['PovStatsData.csv',
#  'PovStatsCountry.csv',
#  'poverty.csv',
#  'PovStatsSeries.csv',
#  'lat_long.csv',
#  'PovStatsCountry-Series.csv',
#  'PovStatsFootNote.csv']

# %%
df = pd.read_csv('data/PovStatsSeries.csv')

# %%
df
# Out:
#        Series Code                          Topic  \
# 0   SI.DST.02ND.20   Poverty: Income distribution
# 1   SI.DST.03RD.20   Poverty: Income distribution
# 2   SI.DST.04TH.20   Poverty: Income distribution
# 3   SI.DST.05TH.20   Poverty: Income distribution
# 4   SI.DST.10TH.10   Poverty: Income distribution
# ..             ...                            ...
# 59     SI.SPR.PT10     Poverty: Shared prosperity
# 60  SI.SPR.PT10.ZG     Poverty: Shared prosperity
# 61     SI.SPR.PT60     Poverty: Shared prosperity
# 62  SI.SPR.PT60.ZG     Poverty: Shared prosperity
# 63     SP.POP.TOTL  Health: Population: Structure
#
#                                        Indicator Name  \
# 0                     Income share held by second 20%
# 1                      Income share held by third 20%
# 2                     Income share held by fourth 20%
# 3                    Income share held by highest 20%
# 4                    Income share held by highest 10%
# ...

# %%
df.sample(3)
# Out:
#        Series Code                         Topic  \
# 62  SI.SPR.PT60.ZG    Poverty: Shared prosperity
# 41  SI.POV.RUHC.NC        Poverty: Poverty rates
# 2   SI.DST.04TH.20  Poverty: Income distribution
#
#                                        Indicator Name  \
# 62  Annualized growth in per capita real survey me...
# 41  Rural poverty headcount ratio at national pove...
# 2                     Income share held by fourth 20%
#
#                                      Short definition  \
# 62  The growth rate in the welfare aggregate of to...
# 41                                                NaN
# 2                                                 NaN
#
#                                       Long definition Unit of measure  \
# 62  The growth rate in the welfare aggregate of to...             NaN
# 41  Rural poverty headcount ratio is the percentag...             NaN
# 2   Percentage share of income or consumption is t...               %
#
# ...

# %%
df.columns
# Out:
# Index(['Series Code', 'Topic', 'Indicator Name', 'Short definition',
#        'Long definition', 'Unit of measure', 'Periodicity', 'Base Period',
#        'Other notes', 'Aggregation method', 'Limitations and exceptions',
#        'Notes from original source', 'General comments', 'Source',
#        'Statistical concept and methodology', 'Development relevance',
#        'Related source links', 'Other web links', 'Related indicators',
#        'License Type', 'Unnamed: 20'],
#       dtype='object')

# %%
df['Indicator Name']
# Out:
# 0                       Income share held by second 20%
# 1                        Income share held by third 20%
# 2                       Income share held by fourth 20%
# 3                      Income share held by highest 20%
# 4                      Income share held by highest 10%
#                             ...
# 59    Survey mean consumption or income per capita, ...
# 60    Annualized growth in per capita real survey me...
# 61    Survey mean consumption or income per capita, ...
# 62    Annualized growth in per capita real survey me...
# 63                                    Population, total
# Name: Indicator Name, Length: 64, dtype: object

# %%
gini = 'GINI index (World Bank estimate)'

# %%
df = df[df['Indicator Name'] =='GINI index (World Bank estimate)']

# %%
df
# Out:
#     Series Code                         Topic  \
# 26  SI.POV.GINI  Poverty: Income distribution
#
#                       Indicator Name Short definition  \
# 26  GINI index (World Bank estimate)              NaN
#
#                                       Long definition Unit of measure  \
# 26  Gini index measures the extent to which the di...               %
#
#    Periodicity  Base Period  Other notes Aggregation method  ...  \
# 26      Annual          NaN          NaN                NaN  ...
#
#    Notes from original source  \
# 26                        NaN
#
#                                      General comments  \
# 26  The World Bank’s internationally comparable po...
#
#                                                Source  \
# 26  World Bank, Development Research Group. Data a...
#
#                   Statistical concept and methodology Development relevance  \
# 26  The Gini index measures the area between the L...                   NaN
#
# ...

# %%
df.columns
# Out:
# Index(['Series Code', 'Topic', 'Indicator Name', 'Short definition',
#        'Long definition', 'Unit of measure', 'Periodicity', 'Base Period',
#        'Other notes', 'Aggregation method', 'Limitations and exceptions',
#        'Notes from original source', 'General comments', 'Source',
#        'Statistical concept and methodology', 'Development relevance',
#        'Related source links', 'Other web links', 'Related indicators',
#        'License Type', 'Unnamed: 20'],
#       dtype='object')

# %%
poverty_df =pd.read_csv('povertydata.csv')
# Out:
# /tmp/ipykernel_23243/916899205.py:1: DtypeWarning: Columns (66,67,73,79,82,83,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   poverty_df =pd.read_csv('povertydata.csv')

# %%
poverty_df['GINI index (World Bank estimate)']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 8282     NaN
# 8283     NaN
# 8284     NaN
# 8285    44.3
# 8286     NaN
# Name: GINI index (World Bank estimate), Length: 8287, dtype: float64
